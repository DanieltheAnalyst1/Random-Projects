# %%
import pandas as pd
project = pd.read_csv("QVI_data.csv")
project
# Out:
#         LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0                 1000  2018-10-17          1       1         5
# 1                 1002  2018-09-16          1       2        58
# 2                 1003  2019-03-07          1       3        52
# 3                 1003  2019-03-08          1       4       106
# 4                 1004  2018-11-02          1       5        96
# ...                ...         ...        ...     ...       ...
# 264829         2370701  2018-12-08         88  240378        24
# 264830         2370751  2018-10-01         88  240394        60
# 264831         2370961  2018-10-24         88  240480        70
# 264832         2370961  2018-10-27         88  240481        65
# 264833         2373711  2018-12-14         88  241815        16
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# ...

# %%
project.isna().sum()
# Out:
# LYLTY_CARD_NBR      0
# DATE                0
# STORE_NBR           0
# TXN_ID              0
# PROD_NBR            0
# PROD_NAME           0
# PROD_QTY            0
# TOT_SALES           0
# PACK_SIZE           0
# BRAND               0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# dtype: int64

# %%
project["STORE_NBR"]==77,86,88
# Out:
# (0         False
#  1         False
#  2         False
#  3         False
#  4         False
#            ...
#  264829    False
#  264830    False
#  264831    False
#  264832    False
#  264833    False
#  Name: STORE_NBR, Length: 264834, dtype: bool,
#  86,
#  88)

# %%
# Filtering the data according to store number

Review = project[project["STORE_NBR"].isin([70,86,88])]
Review
# Out:
#         LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 66093            70000  2018-07-31         70   67482        24
# 66094            70000  2018-10-27         70   67483         5
# 66095            70000  2018-11-05         70   67484        20
# 66096            70000  2019-06-19         70   67485        70
# 66097            70001  2018-09-07         70   67486        46
# ...                ...         ...        ...     ...       ...
# 264829         2370701  2018-12-08         88  240378        24
# 264830         2370751  2018-10-01         88  240394        60
# 264831         2370961  2018-10-24         88  240480        70
# 264832         2370961  2018-10-27         88  240481        65
# 264833         2373711  2018-12-14         88  241815        16
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 66093      Grain Waves         Sweet Chilli 210g         2        7.2
# ...

# %%
Review.loc[Review["DATE"]=="2019"]
# Out:
# Empty DataFrame
# Columns: [LYLTY_CARD_NBR, DATE, STORE_NBR, TXN_ID, PROD_NBR, PROD_NAME, PROD_QTY, TOT_SALES, PACK_SIZE, BRAND, LIFESTAGE, PREMIUM_CUSTOMER]
# Index: []

# %%
Review["DATE"]=="2019"
# Out:
# 66093     False
# 66094     False
# 66095     False
# 66096     False
# 66097     False
#           ...
# 264829    False
# 264830    False
# 264831    False
# 264832    False
# 264833    False
# Name: DATE, Length: 4787, dtype: bool
