# %%
import pandas as pd
healthcare = pd.read_csv("healthcare-dataset-stroke-data.csv")

healthcare
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# Lenghth:

# %%
len(healthcare["age"])
# Out:
# 5110

# %% [markdown]
# Sum Total:

# %%
healthcare["age"].sum()
# Out:
# 220830

# %% [markdown]
# Average

# %%
healthcare["age"].sum()/len(healthcare["age"])
# Out:
# 43.21526418786693

# %% [markdown]
# Filterring the data that has Age above Average

# %%
filtered_healthcare = healthcare[healthcare['age'] > 43]
filtered_healthcare
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 0      9046    Male   67             0              1          Yes
# 1     51676  Female   61             0              0          Yes
# 2     31112    Male   80             0              1          Yes
# 3     60182  Female   49             0              0          Yes
# 4      1665  Female   79             1              0          Yes
# ...     ...     ...  ...           ...            ...          ...
# 5102  45010  Female   57             0              0          Yes
# 5105  18234  Female   80             1              0          Yes
# 5106  44873  Female   81             0              0          Yes
# 5108  37544    Male   51             0              0          Yes
# 5109  44679  Female   44             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# ...

# %% [markdown]
# Filtering the data that has Age below Average

# %%
filtered_healthcare_low = healthcare[healthcare['age'] < 43]
filtered_healthcare_low
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 31    33879    Male   42             0              0          Yes
# 49    36338  Female   39             1              0          Yes
# 118   31720  Female   38             0              0           No
# 133   31563  Female   38             0              0          Yes
# 162   69768  Female    1             0              0           No
# ...     ...     ...  ...           ...            ...          ...
# 5098    579    Male    9             0              0           No
# 5099   7293    Male   40             0              0          Yes
# 5103  22127  Female   18             0              0           No
# 5104  14180  Female   13             0              0           No
# 5107  19723  Female   35             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 31          Private          Rural              83.41  25.4          Unknown
# ...

# %% [markdown]
# # Chart showing the Sum of hypertension, heart disease and Stroke by Gender

# %%
grouped = healthcare.groupby('gender')[['hypertension', 'stroke', 'heart_disease']].sum()

grouped.plot(kind='bar', stacked=False)

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Sum of hypertension, heart disease and Stroke by Gender')

plt.show()

# %% [markdown]
# # Chart showing the sum of Average glucose level by Gender

# %%
groupeda = healthcare.groupby('gender')[['avg_glucose_level']].sum()

groupeda.plot(kind='bar', stacked=False)

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Sum of Average glucose level by Gender')

plt.show()

# %% [markdown]
# # Chart showing the sum of Hypertension, Stroke and Heart disease by Smoking status

# %%
groupedb = healthcare.groupby('smoking_status')[['hypertension', 'stroke', 'heart_disease']].sum()

groupedb.plot(kind='bar', stacked=False)

plt.xlabel('Smoking Status')
plt.ylabel('Count')
plt.title('Sum of Hypertension, Stroke and Heart disease by Smoking status')

plt.show()

# %% [markdown]
# # Chart on the sum of Hypertension, Stroke and Heart disease by Marital status

# %%
groupedc = healthcare.groupby('ever_married')[['hypertension', 'stroke', 'heart_disease']].sum()

groupedc.plot(kind='bar', stacked=False)

plt.xlabel('Ever Married')
plt.ylabel('Count')
plt.title('Sum of Hypertension, Stroke and Heart disease by Marital status')

plt.show()

# %% [markdown]
# # Chart showing the sum of Hypertension, Stroke and Heart disease by Gender above 43yrs

# %%
groupedd = filtered_healthcare.groupby('gender')[['hypertension', 'stroke', 'heart_disease']].sum()

groupedd.plot(kind='bar', stacked=False)

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Sum of Hypertension, Stroke and Heart disease by Gender above 43yrs')

plt.show()

# %% [markdown]
# # Chart showing the sum of Hypertension, Stroke and Heart disease by Gender below 43yrs

# %%
groupede = filtered_healthcare_low.groupby('gender')[['hypertension', 'stroke', 'heart_disease']].sum()

groupede.plot(kind='bar', stacked=False)

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Sum of Hypertension, Stroke and Heart disease by Gender below 43yrs')

plt.show()

# %% [markdown]
# # Chart showing the sum of Average glucose level by Gender

# %%
groupedf = healthcare.groupby('gender')[['avg_glucose_level']].sum()

groupedf.plot(kind='bar', stacked=False)

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Sum of Average glucose level by Gender')

plt.show()

# %% [markdown]
# # Chart showing the sum of Average glucose level by gender and smoking status

# %%
groupedg = healthcare.groupby(['smoking_status','gender'])[['hypertension', 'stroke', 'heart_disease']].sum()

groupedg.plot(kind='bar', stacked=False)

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Sum of Average glucose level by gender and smoking status')

plt.show()

# %% [markdown]
# # Chart showing the sum of Hypertension, Stroke and Heart disease by Work type

# %%
groupedh = healthcare.groupby(['work_type'])[['hypertension', 'stroke', 'heart_disease']].sum()

groupedh.plot(kind='bar', stacked=False)

plt.xlabel('Work Type')
plt.ylabel('Count')
plt.title('Sum of Hypertension, Stroke and Heart disease by Work type')

plt.show()

# %% [markdown]
# # Chart showing the sum of Average glucose level by Work type

# %%
groupedi = healthcare.groupby(['work_type'])[['avg_glucose_level']].sum()

groupedi.plot(kind='bar', stacked=False)

plt.xlabel('Work Type')
plt.ylabel('Count')
plt.title('Sum of Average glucose level by Work type')

plt.show()
